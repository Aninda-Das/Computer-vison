# %% [markdown]
# <a href="https://colab.research.google.com/github/Aninda-Das/Computer-vison/blob/main/Image_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load image

# %%
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt
img =Image.open('/content/download.png')
img = np.array(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.show()
